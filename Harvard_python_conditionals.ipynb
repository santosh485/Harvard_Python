# %%
x = int(input("what's x: "))
y = int(input("What's y: "))

if x<y:
  print("x is less than y")
if x>y:
  print("x is greater than y")
if x==y:
  print("X is equal to y")
# Out:
# what's x: 5
# What's y: 4
# x is greater than y

# %%
x = int(input("what's x: "))
y = int(input("What's y: "))

if x<y or x>y:
  print("x is not less or greater than y")
else:
  print("X is equal to y")
# Out:
# what's x: 5
# What's y: 5
# X is equal to y

# %%
x = int(input("what's x: "))
y = int(input("What's y: "))

if x!=y:
  print("x is not less or greater than y")
else:
  print("X is equal to y")
# Out:
# what's x: 5
# What's y: 5
# X is equal to y

# %%
score = int(input("Score: "))
if score>=90 and score <100:
  print("Grade: A")
elif score>=10 and score<90:
  print("Grade: B")
else:
  print("F")
# Out:
# Score: 55
# Grade: B

# %%
score = int(input("Score: "))
if 90 <= score <100:
  print("Grade: A")
elif 10 <= score <90:
  print("Grade: B")
else:
  print("F")
# Out:
# Score: 99
# Grade: A

# %%
x = int(input("What's x: "))
if x%2==0:
  print("Even")
else:
  print("Odd")
# Out:
# What's x: 4
# Even

# %%
def main():
  x = int(input("What's x : "))
  if is_even(x):
    print("Even")
  else:
    print("odd")

def is_even(n):
  if n%2==0:
    return True
  else:
    return False
main()
# Out:
# What's x : 4
# Even

# %%
def main():
  x = int(input("What's x : "))
  if is_even(x):
    print("Even")
  else:
    print("odd")

def is_even(n):
  #return n%2==0
  return True if n%2==0 else False
main()
# Out:
# What's x : 4
# Even

# %%
name = input("What's your naeme: ")
if name =="Harry" or name == "Hermione":
  print("Gryffindor")
else:
  print("Who")
# Out:
# What's your naeme: Harry
# Gryffindor

# %%
name = input("What's your naeme: ")

match name:
  case "Harry":
    print("Garry")
  case _:
    print("Who")
# Out:
#   File "<ipython-input-19-d950a3bbde05>", line 3
#     match name:
#           ^
# SyntaxError: invalid syntax
